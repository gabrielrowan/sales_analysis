# %% [markdown]
# ## Conclusion of data exploration
#
# ##### This is an already clean data set, with no duplicates and almost no null values, other than for the State column where this is blank for customers living in countries that do not have states.
#
# ##### It shows sales data from  2003-01-06 to 2005-05-31. The data types are generally already correctly set for each column, with the exception of orderdate

# %%
import pandas as pd

# %%
df = pd.read_csv(r"data\sales_data_sample.csv", encoding="Windows-1252")
pd.set_option('display.max_columns', 26)

# %%
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  Motorcycles    95
# ...

# %% [markdown]
# ### Getting count of dataframe rows

# %%
df.size
# Out:
# 70575

# %% [markdown]
# ### Getting count of the amount of orders

# %%
len(pd.unique(df['ORDERNUMBER']))
# Out:
# 307

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %% [markdown]
# ### Getting the different countries that we have sales data for in this table

# %%
distinct_countries = df['COUNTRY'].unique()
distinct_countries
# Out:
# array(['USA', 'France', 'Norway', 'Australia', 'Finland', 'Austria', 'UK',
#        'Spain', 'Sweden', 'Singapore', 'Canada', 'Japan', 'Italy',
#        'Denmark', 'Belgium', 'Philippines', 'Germany', 'Switzerland',
#        'Ireland'], dtype=object)

# %% [markdown]
# ### Getting the amount of different countries we have sales data for

# %%
len(distinct_countries)
# Out:
# 19

# %% [markdown]
# ### Getting the number of different productlines present in this dataset

# %%
distinct_prodlines = df["PRODUCTLINE"].unique()
distinct_prodlines
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %% [markdown]
# ### Converting date column showing as dtype Object to data column

# %%
df["ORDERDATE"] = pd.to_datetime(df["ORDERDATE"])

# %% [markdown]
# ### Finding earliest order date in dataset

# %%
earliest_date = df["ORDERDATE"].min()
earliest_date
# Out:
# Timestamp('2003-01-06 00:00:00')

# %% [markdown]
# ### Finding latest order date in dataset

# %%
latest_date = df["ORDERDATE"].max()
latest_date
# Out:
# Timestamp('2005-05-31 00:00:00')

# %% [markdown]
# ##### This data is from 2003-01-06 to 2005-05-31

# %% [markdown]
# ### Finding possible category options for deal size

# %%
deal_size_categories = df["DEALSIZE"].unique()
deal_size_categories
# Out:
# array(['Small', 'Medium', 'Large'], dtype=object)

# %% [markdown]
# ### Finding possible shipping status categories

# %%
shipping_status_categories = df["STATUS"].unique()
shipping_status_categories
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
new_df = df[["ORDERNUMBER", "QUANTITYORDERED", "PRICEEACH", "CUSTOMERNAME", "SALES", "ORDERDATE", "PRODUCTCODE", "STATUS", "QTR_ID", "MONTH_ID","YEAR_ID", "PRODUCTLINE", "MSRP", "CITY", "STATE", "COUNTRY", "DEALSIZE" ]]
new_df.shape
# Out:
# (2823, 17)

# %%
new_df.rename(str.lower, axis='columns')
new_df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH              CUSTOMERNAME    SALES  \
# 0        10107               30      95.70         Land of Toys Inc.  2871.00
# 1        10121               34      81.35        Reims Collectables  2765.90
# 2        10134               41      94.74           Lyon Souveniers  3884.34
# 3        10145               45      83.26         Toys4GrownUps.com  3746.70
# 4        10159               49     100.00  Corporate Gift Ideas Co.  5205.27
#
#    ORDERDATE PRODUCTCODE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  \
# 0 2003-02-24    S10_1678  Shipped       1         2     2003  Motorcycles
# 1 2003-05-07    S10_1678  Shipped       2         5     2003  Motorcycles
# 2 2003-07-01    S10_1678  Shipped       3         7     2003  Motorcycles
# 3 2003-08-25    S10_1678  Shipped       3         8     2003  Motorcycles
# 4 2003-10-10    S10_1678  Shipped       4        10     2003  Motorcycles
#
#    MSRP           CITY STATE COUNTRY DEALSIZE
# ...

# %%
renamed_df = new_df.rename(columns={"quantityordered": "quantity_ordered", "priceeach": "price_each", "orderdate": "order_date", "productline": "product_line", "dealsize": "deal_size"})
renamed_df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH              CUSTOMERNAME    SALES  \
# 0        10107               30      95.70         Land of Toys Inc.  2871.00
# 1        10121               34      81.35        Reims Collectables  2765.90
# 2        10134               41      94.74           Lyon Souveniers  3884.34
# 3        10145               45      83.26         Toys4GrownUps.com  3746.70
# 4        10159               49     100.00  Corporate Gift Ideas Co.  5205.27
#
#    ORDERDATE PRODUCTCODE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  \
# 0 2003-02-24    S10_1678  Shipped       1         2     2003  Motorcycles
# 1 2003-05-07    S10_1678  Shipped       2         5     2003  Motorcycles
# 2 2003-07-01    S10_1678  Shipped       3         7     2003  Motorcycles
# 3 2003-08-25    S10_1678  Shipped       3         8     2003  Motorcycles
# 4 2003-10-10    S10_1678  Shipped       4        10     2003  Motorcycles
#
#    MSRP           CITY STATE COUNTRY DEALSIZE
# ...

# %% [markdown]
# ### Check for any duplicate rows

# %%
renamed_df.duplicated().any()
# Out:
# False

# %%
renamed_df.to_csv(r"C:\Users\gabriel\OneDrive\Programming\Kaggle Sales Data\data\sales_data_refined.csv", index=False)
